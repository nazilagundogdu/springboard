# %% [markdown]
# # About This Notebook:
# ## AUdience general public -? raising awareness to recruit volunteers
#
# This notebook investigates the animal intake information at the Albuqeurque City Animal Welfare department between the years of 2020 till July 2025 (the time of this report).
#
# The aim is to understand the trends of the intakes, e.g. any increase or reduction, the most concentrated areas of pick ups, etc to see if any pattern emerges.
#
# ## TOC:
#
# ### 1. Setup
#
# ### 2.
#
# ### 3.

# %% [markdown]
# <a
# ### 1. Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2. Load Data and Prelim Analysis

# %%
df = pd.read_csv('AnimalArrivalReport-2020-25.csv',
                 encoding='utf-16',
                 sep = '\t',
                 parse_dates= True,
                 on_bad_lines='skip')

# %%
df.head()
# Out:
#           Arrival Date Animal Id Animal Type Intake Type          Sex  \
# 0  2020-01-03 00:00:00  A1811429        BIRD        WILD  UNSPECIFIED
# 1  2020-01-23 00:00:00  A1812205        BIRD       STRAY       FEMALE
# 2  2020-01-29 00:00:00  A1812473        BIRD  CONFISCATE       FEMALE
# 3  2020-01-29 00:00:00  A1812474        BIRD  CONFISCATE       FEMALE
# 4  2020-01-29 00:00:00  A1812475        BIRD  CONFISCATE       FEMALE
#
#    Years Old  Months Old Primary Breed Primary Color Secondary Color  \
# 0        NaN         NaN        PIGEON          GRAY             NaN
# 1        1.0         NaN       CHICKEN         BROWN             NaN
# 2        1.0         NaN       CHICKEN         WHITE             NaN
# 3        1.0         NaN       CHICKEN         WHITE             NaN
# 4        1.0         NaN       CHICKEN         WHITE             NaN
#
#           Where Picked Up Outcome Type
# 0              8920 LOMAS   EUTHANASIA
# 1  528 BERNALILLO WALMART     ADOPTION
# 2    804 CROMWELL AVE. SW      RECLAIM
# 3    804 CROMWELL AVE. SW      RECLAIM
# 4    804 CROMWELL AVE. SW      RECLAIM

# %%
df.shape
# Out:
# (96751, 12)

# %% [markdown]
# Let's check for `null` values and duplicates.
#
# The `.info()` method below shows some null values in columns ['Years Old', 'Months Old','Primary Color', 'Secondary Color', 'Where Picked Up']. Let's quantify the missing values by using `.isnull().sum()` method.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96751 entries, 0 to 96750
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Arrival Date     96751 non-null  object
#  1   Animal Id        96751 non-null  object
#  2   Animal Type      96751 non-null  object
#  3   Intake Type      96751 non-null  object
#  4   Sex              96751 non-null  object
#  5   Years Old        42830 non-null  float64
#  6   Months Old       45835 non-null  float64
#  7   Primary Breed    96751 non-null  object
#  8   Primary Color    96745 non-null  object
#  9   Secondary Color  53186 non-null  object
#  10  Where Picked Up  76146 non-null  object
#  11  Outcome Type     96751 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 8.9+ MB

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Years Old          53921
# Months Old         50916
# Secondary Color    43565
# Where Picked Up    20605
# Primary Color          6
# Arrival Date           0
# Animal Id              0
# Animal Type            0
# Intake Type            0
# Sex                    0
# Primary Breed          0
# Outcome Type           0
# dtype: int64

# %% [markdown]
# It is possible that in cases when an animal is below 1 years old, only the `Months Old` column is filled and vise verca. Let's verify that.

# %%
df_age_null = df[(df['Years Old'].isnull() & df['Months Old'].isnull())]

# %%
df_age_null.shape
# Out:
# (12402, 12)

# %% [markdown]
# I will drop these rows when analyzing based on age, but keeping for other analyses.

# %% [markdown]
# ### 2.1. Visualization

# %% [markdown]
# Let's see what the distribution of animal types looks like. My guess is the "dog" category is going to have the highest concentration.

# %%
counts = df['Animal Type'].value_counts(ascending=False)  

plt.bar(counts.index, counts.values)
plt.xticks(rotation=45)
plt.title('Animal Type Frequencies')
plt.xlabel('Animal Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# We see there is some spelling issues that need to be addressed. Let's check to see what issues there are:

# %%
df['Animal Type'].unique()
# Out:
# array(['BIRD', 'CAT', 'CAT       ', 'DOG', 'DOG       ', 'LIVESTOCK',
#        'OTHER', 'WILD'], dtype=object)

# %% [markdown]
# Good. We have 1 spelling issue and that is white space after some animal categories. We can just strip the white space and hopefully consolidate the categories of the same type.

# %%
df['Animal Type'] = df['Animal Type'].str.rstrip()

# %%
df['Animal Type'].unique()
# Out:
# array(['BIRD', 'CAT', 'DOG', 'LIVESTOCK', 'OTHER', 'WILD'], dtype=object)

# %% [markdown]
# Cool. We now have distinct categories without white space. Let's plot a histogram again to see the distribution of admitted animal types.

# %%
counts = df['Animal Type'].value_counts(ascending=False)  

plt.bar(counts.index, counts.values)
plt.xticks(rotation=45)
plt.title('Animal Type Frequencies')
plt.xlabel('Animal Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# As expected, 'dog' has the highest percentage, followed by cat and then other animal types.

# %%
df['Animal Type'].value_counts()
# Out:
# Animal Type
# DOG          52927
# CAT          39998
# OTHER         2276
# BIRD           893
# WILD           602
# LIVESTOCK       55
# Name: count, dtype: int64

# %%
print('% of dogs: ', round(len(df[df['Animal Type'] == 'DOG']) / len(df) * 100, 2))
print('% of cats: ', round(len(df[df['Animal Type'] == 'CAT']) / len(df) * 100, 2))
# Out:
# % of dogs:  54.7
# % of cats:  41.34

# %% [markdown]
# This leaves (100 - (54.7+ 41.34)) = 3.96% for all other animal types. I am going to drop those and focus on dogs and cats. I create a new dataframe `df_dc` that will only have those animal types.

# %%
df_dc = df[(df['Animal Type'] == 'DOG') | (df['Animal Type'] =='CAT')]

# %%
df_dc.head()
# Out:
#             Arrival Date Animal Id Animal Type Intake Type     Sex  Years Old  \
# 893  2020-01-01 00:00:00  A1811359         CAT       STRAY    MALE        3.0
# 894  2020-01-01 00:00:00  A1811360         CAT       STRAY    MALE        3.0
# 895  2020-01-02 00:00:00  A1639097         CAT       STRAY    MALE        2.0
# 896  2020-01-02 00:00:00  A1767674         CAT   OWNER SUR  FEMALE        NaN
# 897  2020-01-02 00:00:00  A1780411         CAT   OWNER SUR  FEMALE        1.0
#
#      Months Old Primary Breed Primary Color Secondary Color  \
# 893         NaN   DOMESTIC LH     ORG TABBY             NaN
# 894         NaN   DOMESTIC SH     BRN TABBY           WHITE
# 895         NaN   DOMESTIC MH      GRAY TAB             NaN
# 896         4.0   DOMESTIC MH     BLK SMOKE             NaN
# 897         6.0   DOMESTIC SH          BUFF             NaN
#
#         Where Picked Up Outcome Type
# 893      98TH / CENTRAL     ADOPTION
# 894       MONROE / ROMA      RECLAIM
# 895  1104 SAN RAFAEL NE      RECLAIM
# 896                 NaN      RECLAIM
# 897                 NaN     ADOPTION

# %%
df_dc.shape
# Out:
# (92925, 12)

# %% [markdown]
# We don't need the 'Animal Id', so, let's drop it.

# %%
df_dc.drop(columns = ['Animal Id'], inplace = True)
# Out:
# /var/folders/z0/lg1vzldj0d36ngcfm638k8y80000gn/T/ipykernel_1238/3336296479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dc.drop(columns = ['Animal Id'], inplace = True)

# %%
df_dc.head()
# Out:
#             Arrival Date Animal Type Intake Type     Sex  Years Old  \
# 893  2020-01-01 00:00:00         CAT       STRAY    MALE        3.0
# 894  2020-01-01 00:00:00         CAT       STRAY    MALE        3.0
# 895  2020-01-02 00:00:00         CAT       STRAY    MALE        2.0
# 896  2020-01-02 00:00:00         CAT   OWNER SUR  FEMALE        NaN
# 897  2020-01-02 00:00:00         CAT   OWNER SUR  FEMALE        1.0
#
#      Months Old Primary Breed Primary Color Secondary Color  \
# 893         NaN   DOMESTIC LH     ORG TABBY             NaN
# 894         NaN   DOMESTIC SH     BRN TABBY           WHITE
# 895         NaN   DOMESTIC MH      GRAY TAB             NaN
# 896         4.0   DOMESTIC MH     BLK SMOKE             NaN
# 897         6.0   DOMESTIC SH          BUFF             NaN
#
#         Where Picked Up Outcome Type
# 893      98TH / CENTRAL     ADOPTION
# 894       MONROE / ROMA      RECLAIM
# 895  1104 SAN RAFAEL NE      RECLAIM
# 896                 NaN      RECLAIM
# 897                 NaN     ADOPTION

# %%
df_dc_grouped = df_dc.groupby(['Animal Type', 'Sex', 'Outcome Type']).size().reset_index(name='Count')

# %%
df_dc_grouped.head()
# Out:
#   Animal Type     Sex Outcome Type  Count
# 0         CAT  FEMALE     ADOPTION  11383
# 1         CAT  FEMALE         DIED    313
# 2         CAT  FEMALE     DISPOSAL     11
# 3         CAT  FEMALE   EMERG EUTH     23
# 4         CAT  FEMALE   EUTHANASIA    744

# %%
sns.catplot(data = df_dc_grouped, 
            x = 'Animal Type',
            y = 'Count',
            hue = 'Sex',
            kind = 'bar')

# %% [markdown]
# Let's drop 'Unspecified' from the 'Sex' column.

# %%
df_dc_grouped_sex = df_dc_grouped[df_dc_grouped['Sex'] != 'UNSPECIFIED']

# %%
sns.catplot(data = df_dc_grouped_sex, 
            x = 'Animal Type',
            y = 'Count',
            hue = 'Outcome Type',
            kind = 'bar')

# %%
df_dc_grouped_sex.head()
# Out:
#   Animal Type     Sex Outcome Type  Count
# 0         CAT  FEMALE     ADOPTION  11383
# 1         CAT  FEMALE         DIED    313
# 2         CAT  FEMALE     DISPOSAL     11
# 3         CAT  FEMALE   EMERG EUTH     23
# 4         CAT  FEMALE   EUTHANASIA    744

# %%
df_dc_outcome = df_dc.groupby(['Outcome Type']).size().reset_index(name='Count')
df_dc_outcome.sort_values(by = 'Count', ascending = False)
# Out:
#         Outcome Type  Count
# 0           ADOPTION  50445
# 9            RECLAIM  12115
# 5             FOSTER  11118
# 4         EUTHANASIA   8863
# 14          TRANSFER   5890
# 1               DIED   1404
# 13  Still at Shelter   1036
# 11            RETURN    764
# 6         FOSTERSURG    678
# 10           RELEASE    197
# 3         EMERG EUTH    159
# 8            MISSING    114
# 12          SURG REL     71
# 2           DISPOSAL     63
# 7                FTA      8

# %% [markdown]
# ### 3. Trends
#
# Reminder:

# %%
df_dc.head()
# Out:
#             Arrival Date Animal Type Intake Type     Sex  Years Old  \
# 893  2020-01-01 00:00:00         CAT       STRAY    MALE        3.0
# 894  2020-01-01 00:00:00         CAT       STRAY    MALE        3.0
# 895  2020-01-02 00:00:00         CAT       STRAY    MALE        2.0
# 896  2020-01-02 00:00:00         CAT   OWNER SUR  FEMALE        NaN
# 897  2020-01-02 00:00:00         CAT   OWNER SUR  FEMALE        1.0
#
#      Months Old Primary Breed Primary Color Secondary Color  \
# 893         NaN   DOMESTIC LH     ORG TABBY             NaN
# 894         NaN   DOMESTIC SH     BRN TABBY           WHITE
# 895         NaN   DOMESTIC MH      GRAY TAB             NaN
# 896         4.0   DOMESTIC MH     BLK SMOKE             NaN
# 897         6.0   DOMESTIC SH          BUFF             NaN
#
#         Where Picked Up Outcome Type
# 893      98TH / CENTRAL     ADOPTION
# 894       MONROE / ROMA      RECLAIM
# 895  1104 SAN RAFAEL NE      RECLAIM
# 896                 NaN      RECLAIM
# 897                 NaN     ADOPTION

# %% [markdown]
# Let's change the 'Arrival Date' column to a less fine grained time frame for easier plotting.
#
# First, set the format of the column to datetime format. Then, create a new column with only year and month.

# %%
df_dc['Arrival Date'] = pd.to_datetime(df_dc['Arrival Date'])

df_dc['Arrival Year-Month'] = df_dc['Arrival Date'].dt.strftime('%Y-%m')
# Out:
# /var/folders/z0/lg1vzldj0d36ngcfm638k8y80000gn/T/ipykernel_1238/2924345701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dc['Arrival Date'] = pd.to_datetime(df_dc['Arrival Date'])
# /var/folders/z0/lg1vzldj0d36ngcfm638k8y80000gn/T/ipykernel_1238/2924345701.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dc['Arrival Year-Month'] = df_dc['Arrival Date'].dt.strftime('%Y-%m')

# %%
df_dc
# Out:
#       Arrival Date Animal Type Intake Type     Sex  Years Old  Months Old  \
# 893     2020-01-01         CAT       STRAY    MALE        3.0         NaN
# 894     2020-01-01         CAT       STRAY    MALE        3.0         NaN
# 895     2020-01-02         CAT       STRAY    MALE        2.0         NaN
# 896     2020-01-02         CAT   OWNER SUR  FEMALE        NaN         4.0
# 897     2020-01-02         CAT   OWNER SUR  FEMALE        1.0         6.0
# ...            ...         ...         ...     ...        ...         ...
# 93813   2025-07-26         DOG       STRAY  FEMALE        NaN         3.0
# 93814   2025-07-26         DOG       STRAY  FEMALE        NaN         5.0
# 93815   2025-07-26         DOG       STRAY    MALE        NaN         4.0
# 93816   2025-07-26         DOG   OWNER SUR    MALE        1.0         6.0
# 93817   2025-07-26         DOG       STRAY  FEMALE        4.0         NaN
#
#         Primary Breed Primary Color Secondary Color       Where Picked Up  \
# 893       DOMESTIC LH     ORG TABBY             NaN        98TH / CENTRAL
# 894       DOMESTIC SH     BRN TABBY           WHITE         MONROE / ROMA
# 895       DOMESTIC MH      GRAY TAB             NaN    1104 SAN RAFAEL NE
# 896       DOMESTIC MH     BLK SMOKE             NaN                   NaN
# 897       DOMESTIC SH          BUFF             NaN                   NaN
# ...               ...           ...             ...                   ...
# 93813   GERM SHEPHERD         BLACK           BROWN      I 25 AND ALAMEDA
# 93814   ALASKAN HUSKY         CREAM             TAN         98TH / GIBSON
# 93815   GERM SHEPHERD         BLACK           BROWN                   O/S
# 93816   LABRADOR RETR    BR BRINDLE             NaN  NOT REGISTERED OWNER
# 93817  FRENCH BULLDOG         BLACK           WHITE     COORS / BLUEWATER
#
#            Outcome Type Arrival Year-Month
# 893            ADOPTION            2020-01
# 894             RECLAIM            2020-01
# 895             RECLAIM            2020-01
# 896             RECLAIM            2020-01
# 897            ADOPTION            2020-01
# ...                 ...                ...
# 93813  Still at Shelter            2025-07
# 93814  Still at Shelter            2025-07
# 93815  Still at Shelter            2025-07
# 93816  Still at Shelter            2025-07
# 93817  Still at Shelter            2025-07
#
# [92925 rows x 12 columns]

# %%
df_dc_outcome = df_dc.groupby(['Arrival Year-Month','Animal Type','Outcome Type']).size().reset_index(name='Count')

# %%
df_dc_outcome.sort_values(by = 'Count', ascending = False)
# Out:
#     Arrival Year-Month Animal Type      Outcome Type  Count
# 307            2021-07         CAT          ADOPTION    581
# 996            2024-07         CAT          ADOPTION    557
# 315            2021-07         DOG          ADOPTION    549
# 807            2023-10         CAT          ADOPTION    541
# 745            2023-07         CAT          ADOPTION    530
# ..                 ...         ...               ...    ...
# 603            2022-11         CAT            RETURN      1
# 969            2024-05         DOG        FOSTERSURG      1
# 970            2024-05         DOG           MISSING      1
# 973            2024-05         DOG  Still at Shelter      1
# 849            2023-11         DOG          SURG REL      1
#
# [1221 rows x 4 columns]

# %% [markdown]
# Keeping the 3 most possible outcomes (for plotting purposes) and 'Euthanasia' ones.

# %%
total_outcomes = df_dc_outcome.groupby('Outcome Type')['Count'].sum().sort_values(ascending=False)
print(total_outcomes)
# Out:
# Outcome Type
# ADOPTION            50445
# RECLAIM             12115
# FOSTER              11118
# EUTHANASIA           8863
# TRANSFER             5890
# DIED                 1404
# Still at Shelter     1036
# RETURN                764
# FOSTERSURG            678
# RELEASE               197
# EMERG EUTH            159
# MISSING               114
# SURG REL               71
# DISPOSAL               63
# FTA                     8
# Name: Count, dtype: int64

# %%
top_outcomes = total_outcomes.nlargest(3).index.tolist()
if 'EUTHANASIA' not in top_outcomes:
    top_outcomes.append('EUTHANASIA')

    
filtered = df_dc_outcome[df_dc_outcome['Outcome Type'].isin(top_outcomes)]

# %%
filtered['Arrival Year-Month'] = pd.to_datetime(filtered['Arrival Year-Month'])


plt.figure(figsize=(12,6))
sns.lineplot(data=filtered, x='Arrival Year-Month', y='Count', hue='Outcome Type')

# Get unique years in your data
years = filtered['Arrival Year-Month'].dt.year.unique()

# For each year, find the first date of that year present in the data
for year in years:
    year_start = pd.Timestamp(f'{year}-01-01')
    plt.axvline(x=year_start, color='gray', linestyle='--', alpha=0.5)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert Arrival Year-Month to datetime (already done)
filtered['Arrival Year-Month'] = pd.to_datetime(filtered['Arrival Year-Month'])

# Create facet grid line plots, one subplot per Animal Type
g = sns.relplot(
    data=filtered,
    x='Arrival Year-Month',
    y='Count',
    hue='Outcome Type',
    kind='line',
    col='Animal Type',
    col_wrap=2,  # wrap after 2 plots per row (adjust as needed)
    height=4,
    aspect=1.5,
    facet_kws={'sharey': False}  # If y-axes should be independent
)

# Get unique years
years = filtered['Arrival Year-Month'].dt.year.unique()

# Add vertical lines to each subplot
for ax in g.axes.flat:
    for year in years:
        year_start = pd.Timestamp(f'{year}-01-01')
        ax.axvline(x=year_start, color='gray', linestyle='--', alpha=0.5)
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
filtered_cats = filtered[filtered['Animal Type'] == 'CAT']

filtered_cats['Arrival Year-Month'] = pd.to_datetime(filtered_cats['Arrival Year-Month'])


plt.figure(figsize=(12,6))
sns.lineplot(data=filtered_cats, x='Arrival Year-Month', y='Count', hue='Outcome Type')

# Get unique years in your data
years = filtered_cats['Arrival Year-Month'].dt.year.unique()

# For each year, find the first date of that year present in the data
for year in years:
    year_start = pd.Timestamp(f'{year}-01-01')
    plt.axvline(x=year_start, color='gray', linestyle='--', alpha=0.5)

# %%
filtered_dogs = filtered[filtered['Animal Type'] == 'DOG']

filtered_dogs['Arrival Year-Month'] = pd.to_datetime(filtered_dogs['Arrival Year-Month'])


plt.figure(figsize=(12,6))
sns.lineplot(data=filtered_dogs, x='Arrival Year-Month', y='Count', hue='Outcome Type')

# Get unique years in your data
years = filtered_dogs['Arrival Year-Month'].dt.year.unique()

# For each year, find the first date of that year present in the data
for year in years:
    year_start = pd.Timestamp(f'{year}-01-01')
    plt.axvline(x=year_start, color='gray', linestyle='--', alpha=0.5)

# %%
cats_outcomes = filtered_cats.groupby('Outcome Type')['Count'].sum().sort_values(ascending=False)
print(cats_outcomes)
# Out:
# Outcome Type
# ADOPTION      22615
# FOSTER         8330
# EUTHANASIA     1865
# RECLAIM        1469
# Name: Count, dtype: int64

# %%
cats_outcomes[0]
# Out:
# 22615

# %%
print('Adoption % in Cats: ', round(cats_outcomes[0]/ sum(cats_outcomes) *100,2))
print('Reclaim % in Cats: ', round(cats_outcomes[1]/ sum(cats_outcomes) *100,2))
print('Euthanasia % in Cats: ', round(cats_outcomes[2]/ sum(cats_outcomes) *100,2))
print('Foster % in Cats: ', round(cats_outcomes[3]/ sum(cats_outcomes) *100,2))
# Out:
# Adoption % in Cats:  65.97
# Reclaim % in Cats:  24.3
# Euthanasia % in Cats:  5.44
# Foster % in Cats:  4.29

# %%
dogs_outcomes = filtered_dogs.groupby('Outcome Type')['Count'].sum().sort_values(ascending=False)
print(dogs_outcomes)
# Out:
# Outcome Type
# ADOPTION      27830
# RECLAIM       10646
# EUTHANASIA     6998
# FOSTER         2788
# Name: Count, dtype: int64

# %%
print('Adoption % in Dogs: ', round(dogs_outcomes[0]/ sum(dogs_outcomes) *100,2))
print('Reclaim % in Dogs: ', round(dogs_outcomes[1]/ sum(dogs_outcomes) *100,2))
print('Euthanasia % in Dogs: ', round(dogs_outcomes[2]/ sum(dogs_outcomes) *100,2))
print('Foster % in Dogs: ', round(dogs_outcomes[3]/ sum(dogs_outcomes) *100,2))
# Out:
# Adoption % in Dogs:  57.66
# Reclaim % in Dogs:  22.06
# Euthanasia % in Dogs:  14.5
# Foster % in Dogs:  5.78

# %%
# Ensure Arrival Date is datetime
df_dc['Arrival Date'] = pd.to_datetime(df_dc['Arrival Date'])

# Create a new column for year
df_dc['Arrival Year'] = df_dc['Arrival Date'].dt.year

# Group by year and animal type, and count
annual_counts = df_dc.groupby(['Arrival Year', 'Animal Type']).size().reset_index(name='Count')

# Optional: Sort for better readability
annual_counts = annual_counts.sort_values(by=['Arrival Year', 'Animal Type'])

# %%
annual_counts
# Out:
#     Arrival Year Animal Type  Count
# 0           2020         CAT   4346
# 1           2020         DOG   7650
# 2           2021         CAT   7751
# 3           2021         DOG   9224
# 4           2022         CAT   8419
# 5           2022         DOG   9695
# 6           2023         CAT   9079
# 7           2023         DOG  10009
# 8           2024         CAT   7284
# 9           2024         DOG  10494
# 10          2025         CAT   3119
# 11          2025         DOG   5855

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.lineplot(data=annual_counts, x='Arrival Year', y='Count', hue='Animal Type', marker='o')
plt.title('Annual Intake of Dogs and Cats')
plt.ylabel('Number of Animals')
plt.xlabel('Year')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=annual_counts, x= 'Arrival Year', y='Count')
plt.title('Distribution of Monthly Intakes by Animal Type')
plt.ylabel('Monthly Intake Count')
plt.xlabel('Animal Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## By Age?

# %%
sns.catplot(data=df, x='Animal Type', y='Years Old', kind='bar')

# %%
sns.catplot(data=df, x='Animal Type', y='Months Old', kind='bar')

# %%
group = df_dc.groupby('Animal Type').size().reset_index(name = 'Count').sort_values(by= 'Count', ascending = False)

# %%
group
# Out:
#   Animal Type  Count
# 1         DOG  52927
# 0         CAT  39998

# %%
sns.

# %%
df_cat = df[df['Animal Type'] == 'CAT']

# %%
df_cat['Sex'].value_counts()
# Out:
# Sex
# FEMALE         19918
# MALE           18993
# UNSPECIFIED     1087
# Name: count, dtype: int64

# %%
df_cat['Outcome Type'].value_counts()
# Out:
# Outcome Type
# ADOPTION            22615
# FOSTER               8330
# TRANSFER             3636
# EUTHANASIA           1865
# RECLAIM              1469
# DIED                  900
# Still at Shelter      538
# FOSTERSURG            315
# EMERG EUTH             79
# RETURN                 79
# MISSING                67
# RELEASE                34
# SURG REL               34
# DISPOSAL               33
# FTA                     4
# Name: count, dtype: int64

# %%
df_cat['Intake Type'].value_counts()
# Out:
# Intake Type
# STRAY         20069
# OWNER SUR      9149
# FOSTER         8211
# RETURN         1195
# CONFISCATE      898
# BORN HERE       225
# TRANSFER        165
# SAFETY           82
# WILD              4
# Name: count, dtype: int64

# %%
# Line plot date by animal type
# Plot for outcome by animal type
# Plot for outcome by animal type per year
# plot for location

# %%
df[df['Animal Type'] == 'OTHER'] # can change it to primary breed
# Out:
#               Arrival Date Animal Id Animal Type Intake Type          Sex  \
# 93873  2020-01-03 00:00:00  A1811468       OTHER       STRAY       FEMALE
# 93874  2020-01-05 00:00:00  A1811520       OTHER   OWNER SUR       FEMALE
# 93875  2020-01-06 00:00:00  A1811557       OTHER       STRAY       FEMALE
# 93876  2020-01-06 00:00:00  A1811558       OTHER       STRAY       FEMALE
# 93877  2020-01-06 00:00:00  A1811559       OTHER       STRAY         MALE
# ...                    ...       ...         ...         ...          ...
# 96144  2025-07-24 00:00:00  A1927180       OTHER       STRAY  UNSPECIFIED
# 96145  2025-07-24 00:00:00  A1927181       OTHER       STRAY  UNSPECIFIED
# 96146  2025-07-25 00:00:00  A1927236       OTHER    TRANSFER  UNSPECIFIED
# 96147  2025-07-25 00:00:00  A1927252       OTHER        WILD  UNSPECIFIED
# 96148  2025-07-26 00:00:00  A1927256       OTHER        WILD  UNSPECIFIED
#
#        Years Old  Months Old Primary Breed Primary Color Secondary Color  \
# 93873        NaN         9.0         DUTCH         BLACK           WHITE
# 93874        2.0         NaN    GUINEA PIG      TRICOLOR             NaN
# 93875        2.0         NaN     RABBIT SH         BLACK            GRAY
# 93876        2.0         NaN     RABBIT LH         BLACK            GRAY
# 93877        2.0         NaN     RABBIT LH         BLACK            GRAY
# ...          ...         ...           ...           ...             ...
# 96144        NaN         NaN       HAMSTER           TAN             NaN
# 96145        NaN         NaN       HAMSTER         WHITE           BLACK
# 96146        3.0         NaN         SNAKE         GREEN           GREEN
# 96147        NaN         NaN         SNAKE         BLACK             NaN
# 96148        NaN         NaN         SNAKE         BROWN           BLACK
#
#              Where Picked Up      Outcome Type
# 93873     MCKINNEY / ACADEMY          ADOPTION
# 93874                    NaN          ADOPTION
# 93875       3300 PROSPECT AV          ADOPTION
# 93876       3300 PROSPECT AV          ADOPTION
# 93877       3300 PROSPECT AV          ADOPTION
# ...                      ...               ...
# 96144  5009 EL CORTE MIRAMAR  Still at Shelter
# 96145  5009 EL CORTE MIRAMAR  Still at Shelter
# 96146        2601 CENTRAL SW          TRANSFER
# 96147   14820 CENTRAL AVE SE            RETURN
# 96148   2316 ARROYO VISTA NW            RETURN
#
# [2276 rows x 12 columns]

# %%
df['Animal Type'] = df.apply(lambda row: row['Primary Breed'] if row['Animal Type'] == 'OTHER' 
                             else row['Animal Type'],
                             axis =1)

# %%
df['Animal Type'].value_counts()
# Out:
# Animal Type
# DOG                52927
# CAT                39998
# BIRD                 893
# RABBIT SH            760
# GUINEA PIG           712
# WILD                 602
# RABBIT LH            129
# TURTLE                84
# SNAKE                 69
# FERRET                66
# RAT                   66
# LIVESTOCK             55
# HAMSTER               41
# LIZARD                33
# MOUSE                 32
# TORTOISE              31
# HOTOT                 30
# TROPICAL              25
# NEW ZEALAND WHT       16
# DUTCH                 14
# SQUIRREL              13
# TERRAPIN              13
# LOP-ENGLISH           12
# REX                   11
# LOP-MINI              11
# NETHERLND DWARF       10
# CALIFORNIAN           10
# LOP-HOLLAND            8
# FROG                   8
# ANGORA-ENGLISH         7
# CHINCHILLA             7
# COLD WATER             7
# DEGU                   6
# AMERICAN               6
# LOP-FRENCH             5
# COYOTE                 4
# GERBIL                 4
# ENGLISH SPOT           4
# LOP-AMER FUZZY         3
# FLEMISH GIANT          3
# BAT                    3
# HEDGEHOG               2
# RACCOON                2
# SATIN                  1
# AMERICAN SABLE         1
# SUGAR GLIDER           1
# POLISH                 1
# JERSEY WOOLY           1
# VOLE                   1
# DWARF HOTOT            1
# PRAIRIE DOG            1
# FOX                    1
# Name: count, dtype: int64

# %%
group = df.groupby('Animal Type').size().reset_index(name = 'Count').sort_values(by= 'Count', ascending = False)

# %%
group.head()
# Out:
#    Animal Type  Count
# 11         DOG  52927
# 6          CAT  39998
# 4         BIRD    893
# 38   RABBIT SH    760
# 20  GUINEA PIG    712

# %%
group.drop()

# %%
group.iloc[0:2, :].boxplot(column='Count', by='Animal Type')
# Out:
# <Axes: title={'center': 'Count'}, xlabel='Animal Type'>
